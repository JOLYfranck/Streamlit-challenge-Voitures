# %%
import streamlit as st
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('https://raw.githubusercontent.com/murpi/wilddata/master/quests/cars.csv', sep=',')
df
# Out:
#       mpg  cylinders  cubicinches   hp  weightlbs  time-to-60  year continent
# 0    14.0          8          350  165       4209          12  1972       US.
# 1    31.9          4           89   71       1925          14  1980   Europe.
# 2    17.0          8          302  140       3449          11  1971       US.
# 3    15.0          8          400  150       3761          10  1971       US.
# 4    30.5          4           98   63       2051          17  1978       US.
# ..    ...        ...          ...  ...        ...         ...   ...       ...
# 256  17.0          8          305  130       3840          15  1980       US.
# 257  36.1          4           91   60       1800          16  1979    Japan.
# 258  22.0          6          232  112       2835          15  1983       US.
# 259  18.0          6          232  100       3288          16  1972       US.
# 260  22.0          6          250  105       3353          15  1977       US.
#
# [261 rows x 8 columns]

# %%
dfeurope = df[df['continent'].str.contains('Europe')]

# %%
dfeurope.head()
# Out:
#      mpg  cylinders  cubicinches   hp  weightlbs  time-to-60  year continent
# 1   31.9          4           89   71       1925          14  1980   Europe.
# 8   25.4          5          183   77       3530          20  1980   Europe.
# 11  34.3          4           97   78       2188          16  1981   Europe.
# 19  24.0          4          107   90       2430          15  1971   Europe.
# 21  21.5          4          121  110       2600          13  1978   Europe.

# %%
sns.scatterplot(data=df, x = 'cubicinches', y = 'hp', hue = 'weightlbs', palette='GnBu')
scatterplot = sns.scatterplot(data=df, x = 'cubicinches', y = 'hp', hue = 'weightlbs', palette='GnBu')
# Out:
# <AxesSubplot:xlabel='cubicinches', ylabel='hp'>

# %%
df_corr = df.corr()

# %%
df_corr
# Out:
#                   mpg  cylinders  cubicinches        hp  weightlbs  \
# mpg          1.000000  -0.776710    -0.802201 -0.774905  -0.824134
# cylinders   -0.776710   1.000000     0.951137  0.845155   0.894864
# cubicinches -0.802201   0.951137     1.000000  0.906599   0.925860
# hp          -0.774905   0.845155     0.906599  1.000000   0.857820
# weightlbs   -0.824134   0.894864     0.925860  0.857820   1.000000
# time-to-60   0.509070  -0.578161    -0.610989 -0.744873  -0.477976
# year         0.550441  -0.322239    -0.350074 -0.383869  -0.278216
#
#              time-to-60      year
# mpg            0.509070  0.550441
# cylinders     -0.578161 -0.322239
# cubicinches   -0.610989 -0.350074
# hp            -0.744873 -0.383869
# weightlbs     -0.477976 -0.278216
# time-to-60     1.000000  0.312311
# year           0.312311  1.000000

# %%
sns.heatmap(df_corr)
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(data=df)
